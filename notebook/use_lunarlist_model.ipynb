# %%
# !git clone https://github.com/wannaphong/NeMo.git
# Out:
# Cloning into 'NeMo'...
# remote: Enumerating objects: 123821, done.
# remote: Counting objects: 100% (419/419), done.
# remote: Compressing objects: 100% (362/362), done.
# remote: Total 123821 (delta 195), reused 157 (delta 57), pack-reused 123402
# Receiving objects: 100% (123821/123821), 297.04 MiB | 20.81 MiB/s, done.
# Resolving deltas: 100% (93455/93455), done.

# %%
cd NeMo
# Out:
# /content/NeMo

# %%
# !pip install -q -e .[tts]
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 77.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.4/653.4 kB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 77.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 51.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 48.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 71.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 58.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 18.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 86.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.4 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
#   Building wheel for youtokentome (setup.py) ... done
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Building editable for nemo-toolkit (pyproject.toml) ... done
#   Building wheel for wget (setup.py) ... done
#   Building wheel for distance (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for cdifflib (pyproject.toml) ... done
#   Building wheel for pathtools (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.3.2 requires setuptools>65.5.1, but you have setuptools 65.5.1 which is incompatible.

# %%
# !pip install -q pythaitts
# Out:
# Found existing installation: PyThaiTTS 0.2.0
# Uninstalling PyThaiTTS-0.2.0:
#   Successfully uninstalled PyThaiTTS-0.2.0
#      - 214.6 kB 5.2 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for PyThaiTTS (setup.py) ... done

# %%
from pythaitts import TTS

# %%
tts = TTS(pretrained="lunarlist")
# Out:
# [NeMo I 2023-07-19 08:14:27 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.20.0rc0/tts_en_libritts_multispeaker_univnet/74805fd10315e0a1a4bfe0f7b55ee1b5/tts_en_libritts_multispeaker_univnet.nemo.
# [NeMo I 2023-07-19 08:14:27 cloud:64] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.20.0rc0/tts_en_libritts_multispeaker_univnet/74805fd10315e0a1a4bfe0f7b55ee1b5/tts_en_libritts_multispeaker_univnet.nemo
# [NeMo I 2023-07-19 08:14:27 common:913] Instantiating model from pre-trained checkpoint
# [NeMo W 2023-07-19 08:14:29 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.AudioDataset
#       manifest_filepath: /home/tkdrlf9202/Datasets/LibriTTS-22k/train-all.json
#       max_duration: null
#       min_duration: 0.75
#       n_segments: 16384
#       trim: false
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 8
#       num_workers: 4
#
# [NeMo W 2023-07-19 08:14:29 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.AudioDataset
#       manifest_filepath: /home/tkdrlf9202/Datasets/LibriTTS-22k/dev-clean-mini.json
#       max_duration: null
#       min_duration: null
#       n_segments: -1
#       trim: false
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 1
# [NeMo I 2023-07-19 08:14:29 features:289] PADDING: 0
# [NeMo I 2023-07-19 08:14:29 features:297] STFT using exact pad
# [NeMo I 2023-07-19 08:14:29 features:289] PADDING: 0
# [NeMo I 2023-07-19 08:14:29 features:297] STFT using exact pad
# [NeMo I 2023-07-19 08:14:30 save_restore_connector:249] Model UnivNetModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.20.0rc0/tts_en_libritts_multispeaker_univnet/74805fd10315e0a1a4bfe0f7b55ee1b5/tts_en_libritts_multispeaker_univnet.nemo.
# [NeMo W 2023-07-19 08:14:30 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.asr.data.audio_to_text.AudioToCharDataset
#       manifest_filepath: trim_voice5/common_train.json
#       max_duration: null
#       min_duration: 0.1
#       trim: false
#       int_values: false
#       normalize: false
#       sample_rate: 22050
#       parser: base
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 32
#       num_workers: 5
#
# [NeMo W 2023-07-19 08:14:30 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.asr.data.audio_to_text.AudioToCharDataset
#       manifest_filepath: trim_voice5/common_test.json
#       max_duration: null
#       min_duration: 0.1
#       int_values: false
#       normalize: false
#       sample_rate: 22050
#       trim: false
#       parser: base
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 32
#       num_workers: 5
# [NeMo I 2023-07-19 08:14:30 features:289] PADDING: 16
# [NeMo I 2023-07-19 08:14:31 save_restore_connector:249] Model Tacotron2Model was successfully restored from /root/.cache/huggingface/hub/models--lunarlist--tts-thai-last-step/snapshots/8986ab3f49a66369b35bcaa4a1a78d7550058608/tts-thai-last-step.nemo.

# %%
import IPython

# %%
file = tts.tts("ภาษาไทย ง่าย มาก มาก",filename="cat.wav")

# %%
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave = tts.tts("ภาษาไทย ง่าย มาก มาก",return_type="waveform")
IPython.display.Audio(wave, rate=22010) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
