# %%
# !pip install -q pythaitts

# %%
from pythaitts import TTS

# %%
tts = TTS(pretrained="lunarlist_onnx")

# %%
import IPython

# %%
file = tts.tts("ภาษาไทย ง่าย มาก มาก",filename="cat.wav")

# %%
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave[0][0]
# Out:
# array([[-0.00015215, -0.00042837, -0.00048692, ...,  0.00796382,
#          0.00965735,  0.01095489]], dtype=float32)

# %%
wave = tts.tts("ภาษาไทย ง่าย มาก มาก",return_type="waveform")
IPython.display.Audio(wave[0][0, 0, :], rate=22050) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file = tts.tts("ภาษาไทยตัดคำได้นานแล้ว")

# %%
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file = tts.tts("ภาษา ไทย ตัด คำ ได้ นาน แล้ว")

# %%
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
